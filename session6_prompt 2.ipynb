# %%
Date: "10/18/2024"
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
def sin_graph(a):
    pi = np.pi
    x = np.arange(0, 2*pi, 0.001)
    y = np.sin(x)
    plt.plot(x,y,'b-')
    plt.xlabel("x")
    plt.ylabel(a)
    plt.show
    
if __name__=="__main__":
    sin_graph('sin(x)')

# %% [markdown]
# First, we must import both numpy and matplotlib
#
# We then define a function (with an argument) in which the x-axis will go from 0 to 2pi in increments of 0.001 using numpy.arange
#
# The argument will allow us to recall the function in the third cell to label the y-axis correctly.
#
# We set y as the sin of x and label the axis accrodingly
#
# Lastly, we initalize the code using the if __name__=="__main__" statement

# %%
def cos_graph(b):
    pi = np.pi
    x = np.arange(0, 2*pi, 0.001)
    y = np.cos(x)
    plt.plot(x,y,'r-')
    plt.xlabel("x")
    plt.ylabel(b)
    plt.show()
    
if __name__=="__main__":
    cos_graph('cos(x)')

# %% [markdown]
# Following the same logic as above, we define x as going from 0 to 2 pi with 1000 points in between for more precision.
#
# The function should still have an argument to be able to label the correct y-axis when it is recalled later in cell 3.
#
# We set the y-axis as cos of x and label the x and y aixs accordingly.
#
# Once again, initialize the function.

# %%
def cos_and_sin_graph():
    pi = np.pi
    sin_graph('y')
    cos_graph('y')
    plt.show()
    
if __name__=="__main__":
    cos_and_sin_graph()

# %% [markdown]
# Define a function in which you set up the x-axis as going from 0 to 2pi with 1000 entries.
#
# Recall the functions with the argument 'y' to have a correctly labeled y-axis.
#
# Initialize the code.

# %%
pi = np.pi
x = np.arange(0, 2*pi, 0.001)
y1 = np.sin(x)
y2 = np.cos(x)
for i in range(0, 10):
    print(f'{x[i] :20} {y1[i] :>23} {y2[i] :>20}')
# Out:
#                  0.0                     0.0                  1.0
#                0.001   0.0009999998333333417   0.9999995000000417
#                0.002   0.0019999986666669333   0.9999980000006666
#                0.003    0.002999995500002025    0.999995500003375
#                0.004    0.003999989333341867   0.9999920000106668
#                0.005    0.004999979166692708   0.9999875000260418
#                0.006      0.0059999640000648   0.9999820000540001
#                0.007    0.006999942833473391   0.9999755001000417
#                0.008    0.007999914666939733   0.9999680001706664
# 0.009000000000000001    0.008999878500492076   0.9999595002733743

# %% [markdown]
# Using numpy's functions, set x to be between 0 and 2pi with 1000 entries. Define a variable (y1) that is equal to sin of x and another (y2) that is cos of x.
#
# Use a for loop with range 0 to 10 (to repeat it 10 times) that, using f strings, prints out the values of x, y1, and y2 in colums.
